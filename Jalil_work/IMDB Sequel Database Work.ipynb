# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %matplotlib inline

# %%
con = sqlite3.connect('im.db')
cursor_obj = con.cursor()

imdb = pd.read_sql("""
SELECT *
FROM movie_ratings
INNER JOIN movie_basics ON movie_ratings.movie_id=movie_basics.movie_id;
""", con)


imdb
# Out:
#          movie_id  averagerating  numvotes    movie_id  \
# 0      tt10356526            8.3        31  tt10356526
# 1      tt10384606            8.9       559  tt10384606
# 2       tt1042974            6.4        20   tt1042974
# 3       tt1043726            4.2     50352   tt1043726
# 4       tt1060240            6.5        21   tt1060240
# ...           ...            ...       ...         ...
# 73851   tt9805820            8.1        25   tt9805820
# 73852   tt9844256            7.5        24   tt9844256
# 73853   tt9851050            4.7        14   tt9851050
# 73854   tt9886934            7.0         5   tt9886934
# 73855   tt9894098            6.3       128   tt9894098
#
#                                            primary_title  \
# 0                                       Laiye Je Yaarian
# 1                                             Borderless
# 2                                              Just Inès
# 3                                 The Legend of Hercules
# 4                                              Até Onde?
# ...                                                  ...
# 73851                                              Caisa
# 73852  Code Geass: Lelouch of the Rebellion - Glorifi...
# 73853                                            Sisters
# 73854                                  The Projectionist
# 73855                                             Sathru
#
#                                          original_title  start_year  \
# 0                                      Laiye Je Yaarian        2019
# 1                                            Borderless        2019
# 2                                             Just Inès        2010
# 3                                The Legend of Hercules        2014
# 4                                             Até Onde?        2011
# ...                                                 ...         ...
# 73851                                             Caisa        2018
# 73852  Code Geass: Lelouch of the Rebellion Episode III        2018
# 73853                                           Sisters        2019
# 73854                                 The Projectionist        2019
# 73855                                            Sathru        2019
#
#        runtime_minutes                    genres
# 0                117.0                   Romance
# 1                 87.0               Documentary
# 2                 90.0                     Drama
# 3                 99.0  Action,Adventure,Fantasy
# 4                 73.0          Mystery,Thriller
# ...                ...                       ...
# 73851             84.0               Documentary
# 73852            120.0   Action,Animation,Sci-Fi
# 73853              NaN              Action,Drama
# 73854             81.0               Documentary
# 73855            129.0                  Thriller
#
# [73856 rows x 9 columns]

# %%
imdb = imdb.set_axis(['movie_id', 'averagerating', 'numvotes', 'movie_id_2', 'primary_title', 'original_title', 'start_year', 'runtime_minutes', 'genres'], axis=1)

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         73856 non-null  object
#  1   averagerating    73856 non-null  float64
#  2   numvotes         73856 non-null  int64
#  3   movie_id_2       73856 non-null  object
#  4   primary_title    73856 non-null  object
#  5   original_title   73856 non-null  object
#  6   start_year       73856 non-null  int64
#  7   runtime_minutes  66236 non-null  float64
#  8   genres           73052 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 5.1+ MB

# %%
imdb.head()
# Out:
#      movie_id  averagerating  numvotes  movie_id_2           primary_title  \
# 0  tt10356526            8.3        31  tt10356526        Laiye Je Yaarian
# 1  tt10384606            8.9       559  tt10384606              Borderless
# 2   tt1042974            6.4        20   tt1042974               Just Inès
# 3   tt1043726            4.2     50352   tt1043726  The Legend of Hercules
# 4   tt1060240            6.5        21   tt1060240               Até Onde?
#
#            original_title  start_year  runtime_minutes  \
# 0        Laiye Je Yaarian        2019            117.0
# 1              Borderless        2019             87.0
# 2               Just Inès        2010             90.0
# 3  The Legend of Hercules        2014             99.0
# 4               Até Onde?        2011             73.0
#
#                      genres
# 0                   Romance
# 1               Documentary
# 2                     Drama
# 3  Action,Adventure,Fantasy
# 4          Mystery,Thriller

# %%
imdb.sort_values(by=['runtime_minutes'], ascending = False)
# Out:
#         movie_id  averagerating  numvotes movie_id_2          primary_title  \
# 44210  tt8273150            5.0        17  tt8273150              Logistics
# 12828  tt2659636            6.2        69  tt2659636   Modern Times Forever
# 34936  tt2008009            8.9       219  tt2008009              The Clock
# 62024  tt8677246            8.6         5  tt8677246  Bullfighting Memories
# 39290  tt9047474            8.5       100  tt9047474                La flor
# ...          ...            ...       ...        ...                    ...
# 73843  tt9657910            5.0         7  tt9657910                Trilece
# 73844  tt9668598            5.5       317  tt9668598               Musabbar
# 73848  tt9722952            7.0         6  tt9722952             O Is Bende
# 73850  tt9783738            7.4         7  tt9783738     Bangkok Dark Tales
# 73853  tt9851050            4.7        14  tt9851050                Sisters
#
#               original_title  start_year  runtime_minutes  \
# 44210              Logistics        2012          51420.0
# 12828   Modern Times Forever        2011          14400.0
# 34936              The Clock        2010           1440.0
# 62024  Bullfighting Memories        2017           1100.0
# 39290                La flor        2018            808.0
# ...                      ...         ...              ...
# 73843                Trilece        2018              NaN
# 73844               Musabbar        2019              NaN
# 73848             O Is Bende        2019              NaN
# 73850     Bangkok Dark Tales        2019              NaN
# 73853                Sisters        2019              NaN
#
#                       genres
# 44210            Documentary
# 12828            Documentary
# 34936                  Drama
# 62024         Comedy,History
# 39290  Drama,Fantasy,Musical
# ...                      ...
# 73843                History
# 73844        Horror,Thriller
# 73848                 Comedy
# 73850                 Horror
# 73853           Action,Drama
#
# [73856 rows x 9 columns]

# %%
imdb = imdb.drop(index=44210)

# %%
imdb
# Out:
#          movie_id  averagerating  numvotes  movie_id_2  \
# 0      tt10356526            8.3        31  tt10356526
# 1      tt10384606            8.9       559  tt10384606
# 2       tt1042974            6.4        20   tt1042974
# 3       tt1043726            4.2     50352   tt1043726
# 4       tt1060240            6.5        21   tt1060240
# ...           ...            ...       ...         ...
# 73851   tt9805820            8.1        25   tt9805820
# 73852   tt9844256            7.5        24   tt9844256
# 73853   tt9851050            4.7        14   tt9851050
# 73854   tt9886934            7.0         5   tt9886934
# 73855   tt9894098            6.3       128   tt9894098
#
#                                            primary_title  \
# 0                                       Laiye Je Yaarian
# 1                                             Borderless
# 2                                              Just Inès
# 3                                 The Legend of Hercules
# 4                                              Até Onde?
# ...                                                  ...
# 73851                                              Caisa
# 73852  Code Geass: Lelouch of the Rebellion - Glorifi...
# 73853                                            Sisters
# 73854                                  The Projectionist
# 73855                                             Sathru
#
#                                          original_title  start_year  \
# 0                                      Laiye Je Yaarian        2019
# 1                                            Borderless        2019
# 2                                             Just Inès        2010
# 3                                The Legend of Hercules        2014
# 4                                             Até Onde?        2011
# ...                                                 ...         ...
# 73851                                             Caisa        2018
# 73852  Code Geass: Lelouch of the Rebellion Episode III        2018
# 73853                                           Sisters        2019
# 73854                                 The Projectionist        2019
# 73855                                            Sathru        2019
#
#        runtime_minutes                    genres
# 0                117.0                   Romance
# 1                 87.0               Documentary
# 2                 90.0                     Drama
# 3                 99.0  Action,Adventure,Fantasy
# 4                 73.0          Mystery,Thriller
# ...                ...                       ...
# 73851             84.0               Documentary
# 73852            120.0   Action,Animation,Sci-Fi
# 73853              NaN              Action,Drama
# 73854             81.0               Documentary
# 73855            129.0                  Thriller
#
# [73855 rows x 9 columns]

# %%
subset_imdb = imdb[['averagerating', 'runtime_minutes', 'numvotes', 'genres']].sample(500)

# %%
import seaborn as sns
sns.pairplot(data = subset_imdb, corner = True)

# %%
imdb_2 = pd.read_sql("""
SELECT *
FROM movie_basics
INNER JOIN directors ON movie_basics.movie_id = directors.movie_id
INNER JOIN movie_ratings ON directors.movie_id = movie_ratings.movie_id
INNER JOIN persons ON directors.person_id=persons.person_id;
""", con)


imdb_2
# Out:
#          movie_id                    primary_title  \
# 0       tt0063540                        Sunghursh
# 1       tt0063540                        Sunghursh
# 2       tt0063540                        Sunghursh
# 3       tt0063540                        Sunghursh
# 4       tt0066787  One Day Before the Rainy Season
# ...           ...                              ...
# 181382  tt9914642                        Albatross
# 181383  tt9914642                        Albatross
# 181384  tt9914942       La vida sense la Sara Amat
# 181385  tt9914942       La vida sense la Sara Amat
# 181386  tt9916160                       Drømmeland
#
#                     original_title  start_year  runtime_minutes  \
# 0                        Sunghursh        2013            175.0
# 1                        Sunghursh        2013            175.0
# 2                        Sunghursh        2013            175.0
# 3                        Sunghursh        2013            175.0
# 4                  Ashad Ka Ek Din        2019            114.0
# ...                            ...         ...              ...
# 181382                   Albatross        2017              NaN
# 181383                   Albatross        2017              NaN
# 181384  La vida sense la Sara Amat        2019              NaN
# 181385  La vida sense la Sara Amat        2019              NaN
# 181386                  Drømmeland        2019             72.0
#
#                     genres   movie_id  person_id   movie_id  averagerating  \
# 0       Action,Crime,Drama  tt0063540  nm0712540  tt0063540            7.0
# 1       Action,Crime,Drama  tt0063540  nm0712540  tt0063540            7.0
# 2       Action,Crime,Drama  tt0063540  nm0712540  tt0063540            7.0
# 3       Action,Crime,Drama  tt0063540  nm0712540  tt0063540            7.0
# 4          Biography,Drama  tt0066787  nm0002411  tt0066787            7.2
# ...                    ...        ...        ...        ...            ...
# 181382         Documentary  tt9914642  nm5300859  tt9914642            8.5
# 181383         Documentary  tt9914642  nm5300859  tt9914642            8.5
# 181384                None  tt9914942  nm1716653  tt9914942            6.6
# 181385                None  tt9914942  nm1716653  tt9914942            6.6
# 181386         Documentary  tt9916160  nm5684093  tt9916160            6.5
#
#         numvotes  person_id         primary_name  birth_year  death_year  \
# 0             77  nm0712540  Harnam Singh Rawail      1921.0      2004.0
# 1             77  nm0712540  Harnam Singh Rawail      1921.0      2004.0
# 2             77  nm0712540  Harnam Singh Rawail      1921.0      2004.0
# 3             77  nm0712540  Harnam Singh Rawail      1921.0      2004.0
# 4             43  nm0002411            Mani Kaul      1944.0      2011.0
# ...          ...        ...                  ...         ...         ...
# 181382         8  nm5300859         Chris Jordan         NaN         NaN
# 181383         8  nm5300859         Chris Jordan         NaN         NaN
# 181384         5  nm1716653            Laura Jou         NaN         NaN
# 181385         5  nm1716653            Laura Jou         NaN         NaN
# 181386        11  nm5684093   Joost van der Wiel         NaN         NaN
#
#                      primary_profession
# 0              director,writer,producer
# 1              director,writer,producer
# 2              director,writer,producer
# 3              director,writer,producer
# 4                 director,writer,actor
# ...                                 ...
# 181382           director,writer,editor
# 181383           director,writer,editor
# 181384   miscellaneous,actress,director
# 181385   miscellaneous,actress,director
# 181386  director,cinematographer,writer
#
# [181387 rows x 16 columns]

# %%
imdb_2 = imdb_2.drop_duplicates(subset=['movie_id'])
imdb_2.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 4  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 5  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 7  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 8  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres   movie_id  person_id  \
# 0        2013            175.0    Action,Crime,Drama  tt0063540  nm0712540
# 4        2019            114.0       Biography,Drama  tt0066787  nm0002411
# 5        2018            122.0                 Drama  tt0069049  nm0000080
# 7        2018              NaN          Comedy,Drama  tt0069204  nm0611531
# 8        2017             80.0  Comedy,Drama,Fantasy  tt0100275  nm0749914
#
#     movie_id  averagerating  numvotes  person_id          primary_name  \
# 0  tt0063540            7.0        77  nm0712540   Harnam Singh Rawail
# 4  tt0066787            7.2        43  nm0002411             Mani Kaul
# 5  tt0069049            6.9      4517  nm0000080          Orson Welles
# 7  tt0069204            6.1        13  nm0611531  Hrishikesh Mukherjee
# 8  tt0100275            6.5       119  nm0749914            Raoul Ruiz
#
#    birth_year  death_year        primary_profession
# 0      1921.0      2004.0  director,writer,producer
# 4      1944.0      2011.0     director,writer,actor
# 5      1915.0      1985.0     actor,director,writer
# 7      1922.0      2006.0    director,editor,writer
# 8      1941.0      2011.0  director,writer,producer

# %%
imdb_2 = imdb_2.set_axis(['movie_id', 'primary_title', 'original_title', 'start_year', 'runtime_minutes', 'genres', 
                        'movie_id_2', 'person_id',  'movie_id_3', 'averagerating','numvotes', 'person_id_2', 
                        'primary_name', 'birth_year', 'death_year', 'primary_profession'], axis=1)



imdb_2
# Out:
#          movie_id                    primary_title  \
# 0       tt0063540                        Sunghursh
# 4       tt0066787  One Day Before the Rainy Season
# 5       tt0069049       The Other Side of the Wind
# 7       tt0069204                  Sabse Bada Sukh
# 8       tt0100275         The Wandering Soap Opera
# ...           ...                              ...
# 181378  tt9913084                 Diabolik sono io
# 181380  tt9914286                Sokagin Çocuklari
# 181382  tt9914642                        Albatross
# 181384  tt9914942       La vida sense la Sara Amat
# 181386  tt9916160                       Drømmeland
#
#                     original_title  start_year  runtime_minutes  \
# 0                        Sunghursh        2013            175.0
# 4                  Ashad Ka Ek Din        2019            114.0
# 5       The Other Side of the Wind        2018            122.0
# 7                  Sabse Bada Sukh        2018              NaN
# 8            La Telenovela Errante        2017             80.0
# ...                            ...         ...              ...
# 181378            Diabolik sono io        2019             75.0
# 181380           Sokagin Çocuklari        2019             98.0
# 181382                   Albatross        2017              NaN
# 181384  La vida sense la Sara Amat        2019              NaN
# 181386                  Drømmeland        2019             72.0
#
#                       genres movie_id_2  person_id movie_id_3  averagerating  \
# 0         Action,Crime,Drama  tt0063540  nm0712540  tt0063540            7.0
# 4            Biography,Drama  tt0066787  nm0002411  tt0066787            7.2
# 5                      Drama  tt0069049  nm0000080  tt0069049            6.9
# 7               Comedy,Drama  tt0069204  nm0611531  tt0069204            6.1
# 8       Comedy,Drama,Fantasy  tt0100275  nm0749914  tt0100275            6.5
# ...                      ...        ...        ...        ...            ...
# 181378           Documentary  tt9913084  nm0812850  tt9913084            6.2
# 181380          Drama,Family  tt9914286  nm4394529  tt9914286            8.7
# 181382           Documentary  tt9914642  nm5300859  tt9914642            8.5
# 181384                  None  tt9914942  nm1716653  tt9914942            6.6
# 181386           Documentary  tt9916160  nm5684093  tt9916160            6.5
#
#         numvotes person_id_2          primary_name  birth_year  death_year  \
# 0             77   nm0712540   Harnam Singh Rawail      1921.0      2004.0
# 4             43   nm0002411             Mani Kaul      1944.0      2011.0
# 5           4517   nm0000080          Orson Welles      1915.0      1985.0
# 7             13   nm0611531  Hrishikesh Mukherjee      1922.0      2006.0
# 8            119   nm0749914            Raoul Ruiz      1941.0      2011.0
# ...          ...         ...                   ...         ...         ...
# 181378         6   nm0812850       Giancarlo Soldi      1954.0         NaN
# 181380       136   nm4394529     Ahmet Faik Akinci         NaN         NaN
# 181382         8   nm5300859          Chris Jordan         NaN         NaN
# 181384         5   nm1716653             Laura Jou         NaN         NaN
# 181386        11   nm5684093    Joost van der Wiel         NaN         NaN
#
#                      primary_profession
# 0              director,writer,producer
# 4                 director,writer,actor
# 5                 actor,director,writer
# 7                director,editor,writer
# 8              director,writer,producer
# ...                                 ...
# 181378         director,writer,producer
# 181380                  director,writer
# 181382           director,writer,editor
# 181384   miscellaneous,actress,director
# 181386  director,cinematographer,writer
#
# [73103 rows x 16 columns]

# %%
imdb_2.drop('movie_id_2', inplace=True, axis=1)
imdb_2.drop('movie_id_3', inplace=True, axis=1)
imdb_2.drop('person_id_2', inplace=True, axis=1)

# %%
imdb_2
# Out:
#          movie_id                    primary_title  \
# 0       tt0063540                        Sunghursh
# 4       tt0066787  One Day Before the Rainy Season
# 5       tt0069049       The Other Side of the Wind
# 7       tt0069204                  Sabse Bada Sukh
# 8       tt0100275         The Wandering Soap Opera
# ...           ...                              ...
# 181378  tt9913084                 Diabolik sono io
# 181380  tt9914286                Sokagin Çocuklari
# 181382  tt9914642                        Albatross
# 181384  tt9914942       La vida sense la Sara Amat
# 181386  tt9916160                       Drømmeland
#
#                     original_title  start_year  runtime_minutes  \
# 0                        Sunghursh        2013            175.0
# 4                  Ashad Ka Ek Din        2019            114.0
# 5       The Other Side of the Wind        2018            122.0
# 7                  Sabse Bada Sukh        2018              NaN
# 8            La Telenovela Errante        2017             80.0
# ...                            ...         ...              ...
# 181378            Diabolik sono io        2019             75.0
# 181380           Sokagin Çocuklari        2019             98.0
# 181382                   Albatross        2017              NaN
# 181384  La vida sense la Sara Amat        2019              NaN
# 181386                  Drømmeland        2019             72.0
#
#                       genres  person_id  averagerating  numvotes  \
# 0         Action,Crime,Drama  nm0712540            7.0        77
# 4            Biography,Drama  nm0002411            7.2        43
# 5                      Drama  nm0000080            6.9      4517
# 7               Comedy,Drama  nm0611531            6.1        13
# 8       Comedy,Drama,Fantasy  nm0749914            6.5       119
# ...                      ...        ...            ...       ...
# 181378           Documentary  nm0812850            6.2         6
# 181380          Drama,Family  nm4394529            8.7       136
# 181382           Documentary  nm5300859            8.5         8
# 181384                  None  nm1716653            6.6         5
# 181386           Documentary  nm5684093            6.5        11
#
#                 primary_name  birth_year  death_year  \
# 0        Harnam Singh Rawail      1921.0      2004.0
# 4                  Mani Kaul      1944.0      2011.0
# 5               Orson Welles      1915.0      1985.0
# 7       Hrishikesh Mukherjee      1922.0      2006.0
# 8                 Raoul Ruiz      1941.0      2011.0
# ...                      ...         ...         ...
# 181378       Giancarlo Soldi      1954.0         NaN
# 181380     Ahmet Faik Akinci         NaN         NaN
# 181382          Chris Jordan         NaN         NaN
# 181384             Laura Jou         NaN         NaN
# 181386    Joost van der Wiel         NaN         NaN
#
#                      primary_profession
# 0              director,writer,producer
# 4                 director,writer,actor
# 5                 actor,director,writer
# 7                director,editor,writer
# 8              director,writer,producer
# ...                                 ...
# 181378         director,writer,producer
# 181380                  director,writer
# 181382           director,writer,editor
# 181384   miscellaneous,actress,director
# 181386  director,cinematographer,writer
#
# [73103 rows x 13 columns]

# %%
mov_budg =(pd.read_csv('movie_budgets_roi.csv', delimiter=','))
mov_budg.head()
# Out:
#    Unnamed: 0  id  release_date                                        movie  \
# 0           0   1  Dec 18, 2009                                       Avatar
# 1           1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2           2   3   Jun 7, 2019                                 Dark Phoenix
# 3           3   4   May 1, 2015                      Avengers: Age of Ultron
# 4           4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  net_profit         roi
# 0          425000000       760507625       2776345279  2351345279  553.257713
# 1          410600000       241063875       1045663875   635063875  154.667286
# 2          350000000        42762350        149762350  -200237650  -57.210757
# 3          330600000       459005868       1403013963  1072413963  324.384139
# 4          317000000       620181382       1316721747   999721747  315.369636

# %%
mov_budg.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df_master = pd.merge(mov_budg, imdb_2, how='inner', left_on = 'movie', right_on = 'primary_title')
df_master
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      7  Apr 27, 2018                       Avengers: Infinity War
# ...   ..           ...                                          ...
# 2861  62  Dec 31, 2014                         Stories of Our Lives
# 2862  68   Jul 6, 2001                                         Cure
# 2863  73  Jan 13, 2012                                    Newlyweds
# 2864  78  Dec 31, 2018                                       Red 11
# 2865  81  Sep 29, 2015                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  net_profit  \
# 0             425000000       760507625       2776345279  2351345279
# 1             410600000       241063875       1045663875   635063875
# 2             350000000        42762350        149762350  -200237650
# 3             330600000       459005868       1403013963  1072413963
# 4             300000000       678815482       2048134200  1748134200
# ...                 ...             ...              ...         ...
# 2861              15000               0                0      -15000
# 2862              10000           94596            94596       84596
# 2863               9000            4584             4584       -4416
# 2864               7000               0                0       -7000
# 2865               1400               0                0       -1400
#
#              roi   movie_id                                primary_title  ...  \
# 0     553.257713  tt1775309                                       Avatar  ...
# 1     154.667286  tt1298650  Pirates of the Caribbean: On Stranger Tides  ...
# 2     -57.210757  tt6565702                                 Dark Phoenix  ...
# 3     324.384139  tt2395427                      Avengers: Age of Ultron  ...
# 4     582.711400  tt4154756                       Avengers: Infinity War  ...
# ...          ...        ...                                          ...  ...
# 2861 -100.000000  tt3973612                         Stories of Our Lives  ...
# 2862  845.960000  tt1872026                                         Cure  ...
# 2863  -49.066667  tt1880418                                    Newlyweds  ...
# 2864 -100.000000  tt7837402                                       Red 11  ...
# 2865 -100.000000  tt2107644                         A Plague So Pleasant  ...
#
#      start_year  runtime_minutes                    genres  person_id  \
# 0          2011             93.0                    Horror  nm3786927
# 1          2011            136.0  Action,Adventure,Fantasy  nm0551128
# 2          2019            113.0   Action,Adventure,Sci-Fi  nm1334526
# 3          2015            141.0   Action,Adventure,Sci-Fi  nm0923736
# 4          2018            149.0   Action,Adventure,Sci-Fi  nm0751577
# ...         ...              ...                       ...        ...
# 2861       2014             60.0                     Drama  nm5874888
# 2862       2011             93.0                     Drama  nm0948107
# 2863       2011             95.0              Comedy,Drama  nm0122653
# 2864       2019             77.0    Horror,Sci-Fi,Thriller  nm0001675
# 2865       2013             76.0     Drama,Horror,Thriller  nm4766951
#
#      averagerating  numvotes      primary_name birth_year  death_year  \
# 0              6.1        43      Atsushi Wada        NaN         NaN
# 1              6.6    447624      Rob Marshall     1960.0         NaN
# 2              6.0     24451     Simon Kinberg     1973.0         NaN
# 3              7.3    665594       Joss Whedon     1964.0         NaN
# 4              8.5    670926     Anthony Russo     1970.0         NaN
# ...            ...       ...               ...        ...         ...
# 2861           7.5        85        Jim Chuchu        NaN         NaN
# 2862           4.9        11          Bill Yip        NaN         NaN
# 2863           6.4      1436      Edward Burns     1968.0         NaN
# 2864           5.6        43  Robert Rodriguez     1968.0         NaN
# 2865           5.4        72  Benjamin Roberds        NaN         NaN
#
#                      primary_profession
# 0                              director
# 1       director,miscellaneous,producer
# 2              producer,writer,director
# 3              writer,producer,director
# 4              producer,director,writer
# ...                                 ...
# 2861             director,writer,editor
# 2862  assistant_director,producer,actor
# 2863              actor,writer,producer
# 2864           producer,writer,director
# 2865  camera_department,director,writer
#
# [2866 rows x 21 columns]

# %%
z = df_master.groupby(['primary_name'])['roi'].mean().sort_values().to_frame()

# %%
z1=  df_master.groupby(['primary_name'])['net_profit'].mean().sort_values()
zjoin = pd.merge(z1 ,z,on='primary_name')
zjoin.tail(15)
# Out:
#                      net_profit          roi
# primary_name
# Ronnie Del Carmen  6.792360e+08   388.134853
# Colin Trevorrow    7.187636e+08   578.275820
# Peter Jackson      7.243160e+08   289.726406
# Tim Miller         7.430256e+08  1281.078609
# Sam Mendes         7.450740e+08   324.235232
# Lee Unkrich        7.459438e+08   395.222195
# Yarrow Cheney      8.117505e+08  1082.334045
# Christophe Gans    8.438154e+08  1814.577738
# Kyle Balda         1.023032e+09  1373.829428
# Anthony Russo      1.060869e+09   419.658523
# Chi-kin Kwok       1.122470e+09   748.313273
# Chris Buck         1.122470e+09   748.313273
# Adam Green         1.122470e+09   748.313273
# Pete Meads         2.008208e+09  1004.104197
# Atsushi Wada       2.351345e+09   553.257713

# %%
master_sub = df_master[['production_budget', 'net_profit', 'roi', 'runtime_minutes', 'averagerating']].sample(500)

# %%
import seaborn as sns
sns.pairplot(data = master_sub, corner = True)

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.scatterplot(x = 'averagerating', y = 'roi', data = df_master, ax = ax, color = 'red')

ax.set_xlabel('Average Rating')
ax.set_ylabel('Worldwide Gross')
ax.set_title('Average Rating & Roi')
plt.show()

plt.savefig('roi_rating.png', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.scatterplot(x = 'runtime_minutes', y = 'roi', data = df_master, ax = ax, color = 'g')

ax.set_xlabel('Runtime (minutes)')
ax.set_ylabel('Worldwide Gross')
ax.set_title('Film Length & Roi')
plt.show()

plt.savefig('roi_length.png', dpi=300)

# %%
rating_roi=df_master.loc[:,['averagerating','roi']]
correlation=np.corrcoef(rating_roi['averagerating'], rating_roi['roi'])
correlation=correlation[0][1] 
correlation 
# 0.011783996326472042, there is effectivly no correlation between movie rating and ROI
# Out:
# 0.011783996326472042

# %%
np.corrcoef(df_master['runtime_minutes'], df_master['roi'])
# Out:
# array([[nan, nan],
#        [nan,  1.]])

# %%
runtime_roi = df_master.loc[:,['runtime_minutes','roi']]
correlation_run=np.corrcoef(runtime_roi['runtime_minutes'], runtime_roi['roi'])
correlation_run=correlation_run[0][1] 
correlation_run
# Out:
# nan

# %%
df_master.sort_values(by=['averagerating'], ascending = False)
# Out:
#       id  release_date                           movie  production_budget  \
# 1721  86  Jun 23, 2015                      Crossroads             500000
# 1715  67  Feb 15, 2002                      Crossroads           12000000
# 662   16  Dec 27, 2000                         Traffic           48000000
# 2348  29  May 12, 2017                        The Wall            3000000
# 1908  57  Mar 19, 2010                    The Runaways            9500000
# ...   ..           ...                             ...                ...
# 2739  17  Jul 27, 2001                         Jackpot             400000
# 697    3   Nov 4, 1994                    Frankenstein           45000000
# 713   26  Dec 31, 2012                      Foodfight!           45000000
# 1167  44  Apr 23, 2010                      The Losers           25000000
# 1658  48  Feb 11, 2011  Justin Bieber: Never Say Never           13000000
#
#       domestic_gross  worldwide_gross  net_profit         roi   movie_id  \
# 1721               0                0     -500000 -100.000000  tt8106586
# 1715        37188667         57000000    45000000  375.000000  tt8106586
# 662        124107476        208300000   160300000  333.958333  tt4061640
# 2348         1803064          4495262     1495262   49.842067  tt1455256
# 1908         3573673          5278632    -4221368  -44.435453  tt6168914
# ...              ...              ...         ...         ...        ...
# 2739           44452            44452     -355548  -88.887000  tt3309662
# 697         22006296        112006296    67006296  148.902880  tt2286560
# 713                0            73706   -44926294  -99.836209  tt0249516
# 1167        23591432         29863840     4863840   19.455360  tt3746918
# 1658        73013910         99034125    86034125  661.800962  tt1702443
#
#                        primary_title  ... start_year  runtime_minutes  \
# 1721                      Crossroads  ...       2018              NaN
# 1715                      Crossroads  ...       2018              NaN
# 662                          Traffic  ...       2014            110.0
# 2348                        The Wall  ...       2010             78.0
# 1908                    The Runaways  ...       2019            108.0
# ...                              ...  ...        ...              ...
# 2739                         Jackpot  ...       2013            132.0
# 697                     Frankenstein  ...       2011             82.0
# 713                       Foodfight!  ...       2012             91.0
# 1167                      The Losers  ...       2013            112.0
# 1658  Justin Bieber: Never Say Never  ...       2011            105.0
#
#                        genres  person_id averagerating  numvotes  \
# 1721              Documentary  nm2393401           9.3        22
# 1715              Documentary  nm2393401           9.3        22
# 662               Documentary  nm4891189           9.2        64
# 2348              Documentary  nm3198076           9.2         8
# 1908                Adventure  nm3699308           9.2        47
# ...                       ...        ...           ...       ...
# 2739          Comedy,Thriller  nm0004072           2.1       647
# 697              Drama,Horror  nm5098134           1.9        67
# 713   Action,Animation,Comedy  nm0440415           1.9      8248
# 1167                    Drama  nm2807332           1.7        70
# 1658        Documentary,Music  nm0160840           1.6     74978
#
#            primary_name birth_year  death_year  \
# 1721         Ron Yassen        NaN         NaN
# 1715         Ron Yassen        NaN         NaN
# 662      Pete Middleton        NaN         NaN
# 2348   Ricardo Martinez        NaN         NaN
# 1908       Richard Heap        NaN         NaN
# ...                 ...        ...         ...
# 2739      Kaizad Gustad     1968.0         NaN
# 697       Jordan Salkil        NaN         NaN
# 713   Lawrence Kasanoff     1959.0         NaN
# 1167          Yi-an Lou        NaN         NaN
# 1658         Jon M. Chu     1979.0         NaN
#
#                               primary_profession
# 1721                           producer,director
# 1715                           producer,director
# 662              director,cinematographer,editor
# 2348  editorial_department,visual_effects,editor
# 1908             director,editor,cinematographer
# ...                                          ...
# 2739               director,writer,miscellaneous
# 697                     writer,director,producer
# 713                     producer,writer,director
# 1167                       writer,director,actor
# 1658                    producer,writer,director
#
# [2866 rows x 21 columns]

# %%
df_master.sort_values(['averagerating'],ascending=True).groupby('primary_name').head(20)
# Out:
#       id  release_date                           movie  production_budget  \
# 1658  48  Feb 11, 2011  Justin Bieber: Never Say Never           13000000
# 1167  44  Apr 23, 2010                      The Losers           25000000
# 713   26  Dec 31, 2012                      Foodfight!           45000000
# 697    3   Nov 4, 1994                    Frankenstein           45000000
# 1050   6   Jun 5, 2015                 United Passions           30000000
# ...   ..           ...                             ...                ...
# 1908  57  Mar 19, 2010                    The Runaways            9500000
# 662   16  Dec 27, 2000                         Traffic           48000000
# 2348  29  May 12, 2017                        The Wall            3000000
# 1715  67  Feb 15, 2002                      Crossroads           12000000
# 1721  86  Jun 23, 2015                      Crossroads             500000
#
#       domestic_gross  worldwide_gross  net_profit         roi   movie_id  \
# 1658        73013910         99034125    86034125  661.800962  tt1702443
# 1167        23591432         29863840     4863840   19.455360  tt3746918
# 713                0            73706   -44926294  -99.836209  tt0249516
# 697         22006296        112006296    67006296  148.902880  tt2286560
# 1050             918           168832   -29831168  -99.437227  tt2814362
# ...              ...              ...         ...         ...        ...
# 1908         3573673          5278632    -4221368  -44.435453  tt6168914
# 662        124107476        208300000   160300000  333.958333  tt4061640
# 2348         1803064          4495262     1495262   49.842067  tt1455256
# 1715        37188667         57000000    45000000  375.000000  tt8106586
# 1721               0                0     -500000 -100.000000  tt8106586
#
#                        primary_title  ... start_year  runtime_minutes  \
# 1658  Justin Bieber: Never Say Never  ...       2011            105.0
# 1167                      The Losers  ...       2013            112.0
# 713                       Foodfight!  ...       2012             91.0
# 697                     Frankenstein  ...       2011             82.0
# 1050                 United Passions  ...       2014            110.0
# ...                              ...  ...        ...              ...
# 1908                    The Runaways  ...       2019            108.0
# 662                          Traffic  ...       2014            110.0
# 2348                        The Wall  ...       2010             78.0
# 1715                      Crossroads  ...       2018              NaN
# 1721                      Crossroads  ...       2018              NaN
#
#                        genres  person_id averagerating  numvotes  \
# 1658        Documentary,Music  nm0160840           1.6     74978
# 1167                    Drama  nm2807332           1.7        70
# 713   Action,Animation,Comedy  nm0440415           1.9      8248
# 697              Drama,Horror  nm5098134           1.9        67
# 1050      Drama,History,Sport  nm0041474           2.1      3878
# ...                       ...        ...           ...       ...
# 1908                Adventure  nm3699308           9.2        47
# 662               Documentary  nm4891189           9.2        64
# 2348              Documentary  nm3198076           9.2         8
# 1715              Documentary  nm2393401           9.3        22
# 1721              Documentary  nm2393401           9.3        22
#
#            primary_name birth_year  death_year  \
# 1658         Jon M. Chu     1979.0         NaN
# 1167          Yi-an Lou        NaN         NaN
# 713   Lawrence Kasanoff     1959.0         NaN
# 697       Jordan Salkil        NaN         NaN
# 1050  Frédéric Auburtin     1962.0         NaN
# ...                 ...        ...         ...
# 1908       Richard Heap        NaN         NaN
# 662      Pete Middleton        NaN         NaN
# 2348   Ricardo Martinez        NaN         NaN
# 1715         Ron Yassen        NaN         NaN
# 1721         Ron Yassen        NaN         NaN
#
#                               primary_profession
# 1658                    producer,writer,director
# 1167                       writer,director,actor
# 713                     producer,writer,director
# 697                     writer,director,producer
# 1050           assistant_director,director,actor
# ...                                          ...
# 1908             director,editor,cinematographer
# 662              director,cinematographer,editor
# 2348  editorial_department,visual_effects,editor
# 1715                           producer,director
# 1721                           producer,director
#
# [2866 rows x 21 columns]

# %%
horror = df_master.set_index('genres').filter(regex='Horror', axis=0)
horror.sort_values(by=['net_profit'], ascending = False)
# Out:
#                          id  release_date             movie  \
# genres
# Horror                    1  Dec 18, 2009            Avatar
# Horror,Thriller          24   Sep 8, 2017                It
# Horror                    2  Nov 22, 2017              Coco
# Horror                    5  Jul 13, 1990             Ghost
# Horror                   27  Dec 25, 2015      The Revenant
# ...                      ..           ...               ...
# Horror,Mystery,Thriller  10   Jul 1, 2005           Rebound
# Horror                   30  Sep 30, 2019          Unhinged
# Comedy,Horror,Sci-Fi     83  Oct 30, 2015  Freaks of Nature
# Action,Comedy,Horror     24   May 9, 1997      Father's Day
# Drama,Horror,Thriller    78  Apr 21, 2017       The Promise
#
#                          production_budget  domestic_gross  worldwide_gross  \
# genres
# Horror                           425000000       760507625       2776345279
# Horror,Thriller                   35000000       327481748        697457969
# Horror                           175000000       209726015        798008101
# Horror                            22000000       217631306        517600000
# Horror                           135000000       183637894        532938302
# ...                                    ...             ...              ...
# Horror,Mystery,Thriller           45000000        16809014         17492014
# Horror                            29000000               0                0
# Comedy,Horror,Sci-Fi              33000000           70958            70958
# Action,Comedy,Horror              85000000        28681080         35681080
# Drama,Horror,Thriller             90000000         8224288         10551417
#
#                          net_profit          roi   movie_id     primary_title  \
# genres
# Horror                   2351345279   553.257713  tt1775309            Avatar
# Horror,Thriller           662457969  1892.737054  tt1396484                It
# Horror                    623008101   356.004629  tt7002100              Coco
# Horror                    495600000  2252.727273  tt2175671             Ghost
# Horror                    397938302   294.769113  tt3300078      The Revenant
# ...                             ...          ...        ...               ...
# Horror,Mystery,Thriller   -27507986   -61.128858  tt2837194           Rebound
# Horror                    -29000000  -100.000000  tt5940342          Unhinged
# Comedy,Horror,Sci-Fi      -32929042   -99.784976  tt1817771  Freaks of Nature
# Action,Comedy,Horror      -49318920   -58.022259  tt1727261      Father's Day
# Drama,Horror,Thriller     -79448583   -88.276203  tt7232438       The Promise
#
#                            original_title  start_year  runtime_minutes  \
# genres
# Horror                              Abatâ        2011             93.0
# Horror,Thriller                        It        2017            135.0
# Horror                               Coco        2017             98.0
# Horror                              Ghost        2012            118.0
# Horror                       The Revenant        2012             80.0
# ...                                   ...         ...              ...
# Horror,Mystery,Thriller           Rebound        2014             84.0
# Horror                           Unhinged        2017             93.0
# Comedy,Horror,Sci-Fi     Freaks of Nature        2015             92.0
# Action,Comedy,Horror         Father's Day        2011             99.0
# Drama,Horror,Thriller     Puen Tee Raluek        2017            114.0
#
#                          person_id  averagerating  numvotes  \
# genres
# Horror                   nm3786927            6.1        43
# Horror,Thriller          nm0615592            7.4    359123
# Horror                   nm9039216            7.4        35
# Horror                   nm1680452            2.3       205
# Horror                   nm5419512            6.0        20
# ...                            ...            ...       ...
# Horror,Mystery,Thriller  nm2148858            4.2       259
# Horror                   nm4367233            4.2       512
# Comedy,Horror,Sci-Fi     nm0681852            5.9      9670
# Action,Comedy,Horror     nm2377041            6.0      2482
# Drama,Horror,Thriller    nm1637163            6.1       629
#
#                                   primary_name  birth_year  death_year  \
# genres
# Horror                            Atsushi Wada         NaN         NaN
# Horror,Thriller                Andy Muschietti         NaN         NaN
# Horror                            Neil Boultby         NaN         NaN
# Horror                               Puja Bedi         NaN         NaN
# Horror                              Josh Jones         NaN         NaN
# ...                                        ...         ...         ...
# Horror,Mystery,Thriller  Megan Freels Johnston         NaN         NaN
# Horror                               Dan Allen         NaN         NaN
# Comedy,Horror,Sci-Fi          Robbie Pickering         NaN         NaN
# Action,Comedy,Horror           Matthew Kennedy         NaN         NaN
# Drama,Horror,Thriller       Sophon Sakdaphisit         NaN         NaN
#
#                                          primary_profession
# genres
# Horror                                             director
# Horror,Thriller                    director,writer,producer
# Horror                               director,writer,editor
# Horror                        producer,writer,miscellaneous
# Horror                        miscellaneous,director,editor
# ...                                                     ...
# Horror,Mystery,Thriller            producer,writer,director
# Horror                             director,editor,producer
# Comedy,Horror,Sci-Fi                  writer,director,actor
# Action,Comedy,Horror                  actor,writer,producer
# Drama,Horror,Thriller    writer,director,assistant_director
#
# [360 rows x 20 columns]

# %%
type(horror)
# Out:
# pandas.core.frame.DataFrame

# %%
horror.reset_index(inplace = True)
horror

#horror.drop('movie_id_2', inplace=True, axis=0)
#horror.drop(horror.index[1])
# Out:
#                        genres  id  release_date                 movie  \
# 0                      Horror   1  Dec 18, 2009                Avatar
# 1     Action,Adventure,Horror  69  Jun 21, 2013           World War Z
# 2        Action,Horror,Sci-Fi  94  Aug 10, 2018               The Meg
# 3                      Horror   2  Nov 22, 2017                  Coco
# 4       Comedy,Fantasy,Horror  89  May 11, 2012          Dark Shadows
# ..                        ...  ..           ...                   ...
# 355  Adventure,Horror,Mystery  51  Apr 21, 2015                   Ten
# 356   Horror,Mystery,Thriller  51  Apr 21, 2015                   Ten
# 357     Drama,Horror,Thriller  59  Nov 25, 2011            The Ridges
# 358    Horror,Sci-Fi,Thriller  78  Dec 31, 2018                Red 11
# 359     Drama,Horror,Thriller  81  Sep 29, 2015  A Plague So Pleasant
#
#      production_budget  domestic_gross  worldwide_gross  net_profit  \
# 0            425000000       760507625       2776345279  2351345279
# 1            190000000       202359711        531514650   341514650
# 2            178000000       145443742        529530715   351530715
# 3            175000000       209726015        798008101   623008101
# 4            150000000        79727149        238202668    88202668
# ..                 ...             ...              ...         ...
# 355              25000               0                0      -25000
# 356              25000               0                0      -25000
# 357              17300               0                0      -17300
# 358               7000               0                0       -7000
# 359               1400               0                0       -1400
#
#             roi   movie_id  ...        original_title start_year  \
# 0    553.257713  tt1775309  ...                 Abatâ       2011
# 1    179.744553  tt0816711  ...           World War Z       2013
# 2    197.489166  tt4779682  ...               The Meg       2018
# 3    356.004629  tt7002100  ...                  Coco       2017
# 4     58.801779  tt1077368  ...          Dark Shadows       2012
# ..          ...        ...  ...                   ...        ...
# 355 -100.000000  tt2496400  ...                   Ten       2014
# 356 -100.000000  tt6415838  ...                   Ten       2017
# 357 -100.000000  tt1781935  ...            The Ridges       2011
# 358 -100.000000  tt7837402  ...                Red 11       2019
# 359 -100.000000  tt2107644  ...  A Plague So Pleasant       2013
#
#      runtime_minutes  person_id averagerating  numvotes        primary_name  \
# 0               93.0  nm3786927           6.1        43        Atsushi Wada
# 1              116.0  nm0286975           7.0    553751        Marc Forster
# 2              113.0  nm0005509           5.7    114042      Jon Turteltaub
# 3               98.0  nm9039216           7.4        35        Neil Boultby
# 4              113.0  nm0000318           6.2    229818          Tim Burton
# ..               ...        ...           ...       ...                 ...
# 355             83.0  nm4664031           5.4       623  Michael J. Epstein
# 356             82.0  nm4363817           4.7       191        Chris Robert
# 357             89.0  nm4192760           2.9       127     Brandon Landers
# 358             77.0  nm0001675           5.6        43    Robert Rodriguez
# 359             76.0  nm4766951           5.4        72    Benjamin Roberds
#
#     birth_year  death_year                         primary_profession
# 0          NaN         NaN                                   director
# 1       1969.0         NaN                   producer,director,writer
# 2       1963.0         NaN                   producer,director,writer
# 3          NaN         NaN                     director,writer,editor
# 4       1958.0         NaN            producer,miscellaneous,director
# ..         ...         ...                                        ...
# 355        NaN         NaN  sound_department,editor,camera_department
# 356        NaN         NaN                   writer,producer,director
# 357        NaN         NaN      actor,sound_department,art_department
# 358     1968.0         NaN                   producer,writer,director
# 359        NaN         NaN          camera_department,director,writer
#
# [360 rows x 21 columns]

# %%
horror_dir = horror.set_index('primary_profession').filter(regex='director', axis=0)
horror_dir.reset_index(inplace = True)
horror
# Out:
#                        genres  id  release_date                 movie  \
# 0                      Horror   1  Dec 18, 2009                Avatar
# 1     Action,Adventure,Horror  69  Jun 21, 2013           World War Z
# 2        Action,Horror,Sci-Fi  94  Aug 10, 2018               The Meg
# 3                      Horror   2  Nov 22, 2017                  Coco
# 4       Comedy,Fantasy,Horror  89  May 11, 2012          Dark Shadows
# ..                        ...  ..           ...                   ...
# 355  Adventure,Horror,Mystery  51  Apr 21, 2015                   Ten
# 356   Horror,Mystery,Thriller  51  Apr 21, 2015                   Ten
# 357     Drama,Horror,Thriller  59  Nov 25, 2011            The Ridges
# 358    Horror,Sci-Fi,Thriller  78  Dec 31, 2018                Red 11
# 359     Drama,Horror,Thriller  81  Sep 29, 2015  A Plague So Pleasant
#
#      production_budget  domestic_gross  worldwide_gross  net_profit  \
# 0            425000000       760507625       2776345279  2351345279
# 1            190000000       202359711        531514650   341514650
# 2            178000000       145443742        529530715   351530715
# 3            175000000       209726015        798008101   623008101
# 4            150000000        79727149        238202668    88202668
# ..                 ...             ...              ...         ...
# 355              25000               0                0      -25000
# 356              25000               0                0      -25000
# 357              17300               0                0      -17300
# 358               7000               0                0       -7000
# 359               1400               0                0       -1400
#
#             roi   movie_id  ...        original_title start_year  \
# 0    553.257713  tt1775309  ...                 Abatâ       2011
# 1    179.744553  tt0816711  ...           World War Z       2013
# 2    197.489166  tt4779682  ...               The Meg       2018
# 3    356.004629  tt7002100  ...                  Coco       2017
# 4     58.801779  tt1077368  ...          Dark Shadows       2012
# ..          ...        ...  ...                   ...        ...
# 355 -100.000000  tt2496400  ...                   Ten       2014
# 356 -100.000000  tt6415838  ...                   Ten       2017
# 357 -100.000000  tt1781935  ...            The Ridges       2011
# 358 -100.000000  tt7837402  ...                Red 11       2019
# 359 -100.000000  tt2107644  ...  A Plague So Pleasant       2013
#
#      runtime_minutes  person_id averagerating  numvotes        primary_name  \
# 0               93.0  nm3786927           6.1        43        Atsushi Wada
# 1              116.0  nm0286975           7.0    553751        Marc Forster
# 2              113.0  nm0005509           5.7    114042      Jon Turteltaub
# 3               98.0  nm9039216           7.4        35        Neil Boultby
# 4              113.0  nm0000318           6.2    229818          Tim Burton
# ..               ...        ...           ...       ...                 ...
# 355             83.0  nm4664031           5.4       623  Michael J. Epstein
# 356             82.0  nm4363817           4.7       191        Chris Robert
# 357             89.0  nm4192760           2.9       127     Brandon Landers
# 358             77.0  nm0001675           5.6        43    Robert Rodriguez
# 359             76.0  nm4766951           5.4        72    Benjamin Roberds
#
#     birth_year  death_year                         primary_profession
# 0          NaN         NaN                                   director
# 1       1969.0         NaN                   producer,director,writer
# 2       1963.0         NaN                   producer,director,writer
# 3          NaN         NaN                     director,writer,editor
# 4       1958.0         NaN            producer,miscellaneous,director
# ..         ...         ...                                        ...
# 355        NaN         NaN  sound_department,editor,camera_department
# 356        NaN         NaN                   writer,producer,director
# 357        NaN         NaN      actor,sound_department,art_department
# 358     1968.0         NaN                   producer,writer,director
# 359        NaN         NaN          camera_department,director,writer
#
# [360 rows x 21 columns]

# %%
horror_dir = horror_dir.sort_values(by=['roi'], ascending = False)
horror_dir.reset_index(inplace = True)

# %%
horror_dir['roi'].head(20)
# Out:
# 0     41556.474000
# 1     21438.461538
# 2     10075.949000
# 3      8858.633600
# 4      6558.059067
# 5      6336.419800
# 6      5817.067733
# 7      5479.296120
# 8      4141.172100
# 9      4040.796880
# 10     3851.737231
# 11     3798.105556
# 12     2942.219367
# 13     2876.130200
# 14     2824.260233
# 15     2757.142857
# 16     2757.142857
# 17     2756.359840
# 18     2617.924114
# 19     2617.924114
# Name: roi, dtype: float64

# %%
horror_dir.drop('index', inplace=True, axis=1)

# %%
horror_dir_sub = horror_dir.head(3)
horror_dir_sub
# Out:
#          primary_profession                   genres  id  release_date  \
# 0  producer,director,writer  Horror,Mystery,Thriller  80  Jul 10, 2015
# 1  producer,director,writer          Horror,Thriller  37  Oct 17, 1978
# 2  director,producer,writer                   Horror  12   Jan 6, 2012
#
#               movie  production_budget  domestic_gross  worldwide_gross  \
# 0       The Gallows             100000        22764410         41656474
# 1         Halloween             325000        47000000         70000000
# 2  The Devil Inside            1000000        53262945        101759490
#
#    net_profit           roi  ...     primary_title    original_title  \
# 0    41556474  41556.474000  ...       The Gallows       The Gallows
# 1    69675000  21438.461538  ...         Halloween         Halloween
# 2   100759490  10075.949000  ...  The Devil Inside  The Devil Inside
#
#   start_year  runtime_minutes  person_id averagerating  numvotes  \
# 0       2015             81.0  nm3951039           4.2     17763
# 1       2018            106.0  nm0337773           6.6     88395
# 2       2012             83.0  nm0068587           4.2     33522
#
#          primary_name birth_year  death_year
# 0        Chris Lofing        NaN         NaN
# 1  David Gordon Green     1975.0         NaN
# 2  William Brent Bell        NaN         NaN
#
# [3 rows x 21 columns]

# %%
fig, ax = plt.subplots(figsize = (6,4))
sns.barplot(x = 'primary_name', y = 'roi', palette = 'hls', data = horror_dir_sub)
ax.set_title('Top 3 Horror Directors by ROI', size=15)
ax.set_xlabel('Horror Directors', size=15)
ax.set_ylabel('Return on Investment', size=13)
plt.show()

# %%
#Boxplot scratch work



df_master_genre_subset = df_master.set_index('genres').filter(regex=('horror', 'thriller','romance'), axis=0)
df_master_genre_subset.reset_index(inplace = True)



#df_master.boxplot(x = 'primary_name', y = 'roi', 
#data = horror_dir_sub, orient = 'v')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-78c491e0b380> in <module>
#       3
#       4
# ----> 5 df_master_genre_subset = df_master.set_index('genres').filter(regex=('horror', 'thriller','romance'), axis=0)
#       6 df_master_genre_subset.reset_index(inplace = True)
#       7
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in filter(self, items, like, regex, axis)
#    4634                 return matcher.search(ensure_str(x)) is not None
#    4635
# -> 4636             matcher = re.compile(regex)
#    4637             values = labels.map(f)
#    4638             return self.loc(axis=axis)[values]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/re.py in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#     253
#     254 def purge():
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/re.py in _compile(pattern, flags)
#     301         return pattern
#     302     if not sre_compile.isstring(pattern):
# --> 303         raise TypeError("first argument must be string or compiled pattern")
#     304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#
# TypeError: first argument must be string or compiled pattern

# %%
def get_dummies():
    return 'Jeff'

# %%
get_dummies()
# Out:
# 'Jeff'
